# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

performance = pd.read_excel('performance.xlsx')
performance = performance.iloc[:,1:]

# %% [markdown]
# # Grouping by Fleet Type

# %%
# type0: 4x 30kW cars | 4 fast charge points
# type1: 4x 40kW cars | 4 fast charge points
# type2: 4x 70kW cars | 4 fast charge points
# type3: 4x 30kW cars | 2 fast charge points
# type4: 4x 40kW cars | 2 fast charge points
# type5: 4x 70kW cars | 2 fast charge points

# %%
performance.groupby(['fleetType']).mean().iloc[:,1:].round(2)
# Out:
#            dumbRC  leavetimeRC  battRC  smartRC  costRC  dumbCost  \
# fleetType
# 0            10.3          9.4     9.4      8.8     9.1    148.83
# 1             3.4          3.1     3.3      2.8     3.7    130.99
# 2             0.5          0.5     0.4      0.2     1.2    123.40
# 3            18.2         17.4    17.1     17.5    17.8    165.08
# 4            12.3         11.2    11.7     11.9    12.1    153.47
# 5             5.1          4.5     4.0      4.6     5.2    137.53
#
#            leavetimeCost  battCost  smartCost  costCost
# fleetType
# 0                 147.62    146.89     144.45    130.26
# 1                 131.42    130.88     128.51    118.57
# 2                 124.60    123.26     121.92    113.63
# 3                 163.84    163.00     162.61    154.62
# 4                 151.44    152.14     151.76    141.46
# 5                 136.20    134.77     135.02    126.30

# %%
rapidCharges = performance.groupby(['fleetType']).mean().iloc[:,1:-5]
cost = performance.groupby(['fleetType']).mean().iloc[:,-5:]

fig, ax = plt.subplots(figsize=(16,7))
ax.plot(rapidCharges, 'o-')
ax.grid(b=True, which='both', color='0.65', linestyle='-')
ax.set_xlabel('Schedule ID', fontsize=18)
ax.set_title('Rapid Charges', fontsize=20)
ax.legend(['dumb','leavetime','battneeded','battneeded/leavetime','cost-sensitive'])

fig2, ax2 = plt.subplots(figsize=(16,7))
ax2.plot(cost, 'o-')
ax2.grid(b=True, which='both', color='0.65', linestyle='-')
ax2.set_xlabel('Schedule ID', fontsize=18)
ax2.set_title('Cost', fontsize=20)
ax2.legend(['dumb','leavetime','battneeded','battneeded/leavetime','cost-sensitive'])

# %% [markdown]
# # Grouping by schedule

# %%
# shift0 - work shift with break              good
# shift1 - work shift
# shift2 - work shift 2
# shift3 - first shift same (original)        good
# shift4 - second shift same
# shfit5 - national express
# shift6 - taxi
# shift7 - meal delivery
# shift8 - goods delivery                     good
# shift9 - long work shift                    good

# %%
performance.groupby(['schedule']).mean().iloc[:,1:].round(2)
# Out:
#           dumbRC  leavetimeRC  battRC  smartRC  costRC  dumbCost  \
# schedule
# 0           9.00         8.17    7.33     7.83    7.83    165.06
# 1           5.50         5.33    5.67     5.00    5.17    126.02
# 2           9.67         8.67    8.50     8.50    8.67    151.51
# 3          11.33         9.17    9.00     9.33   10.83    173.99
# 4           7.50         6.50    6.83     6.50    7.00    138.21
# 5           6.83         6.67    6.67     6.67    6.67    133.45
# 6           5.67         5.50    5.50     6.17    6.83    118.74
# 7           4.00         4.00    4.50     4.33    4.17    107.27
# 8           2.50         2.00    2.33     1.83    2.17    123.21
# 9          21.00        20.83   20.17    20.17   22.50    194.70
#
#           leavetimeCost  battCost  smartCost  costCost
# schedule
# 0                164.70    161.91     161.91    154.83
# 1                125.48    126.34     124.16    108.87
# 2                150.17    148.60     148.60    139.42
# 3                170.81    169.68     168.65    164.11
# 4                136.17    136.48     134.13    125.57
# 5                133.87    133.20     132.37    120.28
# 6                118.14    118.26     118.32    101.86
# 7                107.85    108.32     106.47     96.90
# 8                122.89    121.98     120.51    107.52
# 9                195.11    193.47     191.99    188.69

# %%
rapidCharges = performance.groupby(['schedule']).mean().iloc[:-1,1:-5]
cost = performance.groupby(['schedule']).mean().iloc[:-1,-5:]

fig, ax = plt.subplots(figsize=(16,7))
ax.plot(rapidCharges, 'o-')
ax.grid(b=True, which='both', color='0.65', linestyle='-')
ax.set_xlabel('Schedule ID', fontsize=18)
ax.set_title('Rapid Charges', fontsize=20)
ax.legend(['dumb','leavetime','battneeded','battneeded/leavetime','cost-sensitive'])

fig2, ax2 = plt.subplots(figsize=(16,7))
ax2.plot(cost, 'o-')
ax2.grid(b=True, which='both', color='0.65', linestyle='-')
ax2.set_xlabel('Schedule ID', fontsize=18)
ax2.set_title('Cost', fontsize=20)
ax2.legend(['dumb','leavetime','battneeded','battneeded/leavetime','cost-sensitive'])
